# %% [markdown]
# # I'm first heading

# %% [markdown]
# ## I'm second heading

# %% [markdown]
# ### I'm third heading

# %% [markdown]
# #### I'm fourth heading

# %% [markdown]
# ##### I'm fifth heading

# %% [markdown]
# ###### I'm sixth heading

# %% [markdown]
# ####### I'm no heading

# %% [markdown]
# ###### I'm sixth heading

# %% [markdown]
# Markdown is the default language for jupyter text edit.
#
# $ single line formula $
# $ \frac{1}{1 - x} = 1 + x + x^2 + \dots = \sum\limits_{i = 0}^{\infty} x^i, x \in (-1, 1) $

# %% [markdown]
# Tables.
#
# |left_______long|center_______long|right_______long|
# |:-|:-:|-:|
# |123|456|789|

# %% [markdown]
# Horizontal line.
#
# ---
#
# Look up.

# %% [markdown]
# Some links.
#
# https://www.google.com

# %% [markdown]
# Take a screen shot and paste it, handy when you write learning notes.
#
# The image is actually base64-encoded and saved.
#
# Careful, not too HD.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Lists.
#
# - xxx
#     - xyz
#     - zyx
# - yyy
# - zzz
#
# 1. xxx
#     1. xyz
#     1. zyx
# 1. yyy
# 1. zzz

# %% [markdown]
# Text styles.
#
# - normal
# - **bold**
# - *italics*
# - ~~stricken~~
# - underlined, no
# - colored, no
